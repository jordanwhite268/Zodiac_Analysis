# %%
import pandas as pd
#Pull csv into pandas dataframe

data = pd.read_csv(r'C:\Users\Jordan\Documents\CodeKY\Capstone_Project_Repo\Data\pantheon_people.csv', delimiter = ",")
len(data)
# Out:
# 11341

# %%
#drop unneeded columns
data = data.drop(columns=['en_curid','numlangs','countryCode','LAT','LON', 'TotalPageViews', 'L_star', 'StdDevPageViews', 'PageViewsEnglish', 'PageViewsNonEnglish', 'AverageViews' , 'HPI'                 ]) 
data.head(5)
# Out:
#               name         birthcity birthstate     countryName countryCode3  \
# 0  Abraham Lincoln       Hodgenville         KY   UNITED STATES          USA
# 1        Aristotle          Stageira        NaN          Greece          GRC
# 2         Ayn Rand  Saint Petersburg        NaN          Russia          RUS
# 3     Andre Agassi         Las Vegas         NV   UNITED STATES          USA
# 4    Aldous Huxley         Godalming        NaN  UNITED KINGDOM          GBR
#
#    continentName birthyear  gender     occupation           industry  \
# 0  North America      1809    Male     POLITICIAN         GOVERNMENT
# 1         Europe      -384    Male    PHILOSOPHER         PHILOSOPHY
# 2         Europe      1905  Female         WRITER           LANGUAGE
# 3  North America      1970    Male  TENNIS PLAYER  INDIVIDUAL SPORTS
# 4         Europe      1894    Male         WRITER           LANGUAGE
#
#          domain
# 0  INSTITUTIONS
# 1    HUMANITIES
# 2    HUMANITIES
# 3        SPORTS
# 4    HUMANITIES

# %%
#replace the invalid vaues
#data2.loc[invalid_values.index, 'Birth_Year'] = pd.NA
#check to see if any values are returned
#invalid_values = data2[data2['Birth_Year'].astype(str).str.contains('[a-zA-Z!@#$%^&*(),.?":{}|<>]', regex=True, na=False)]
#print(invalid_values)

badyr = data['birthyear'].str.extract(r'^(\d{4})', expand=False)
badyr.head(10)
data['birthyear'] = pd.to_numeric(badyr)
data['birthyear'].dtype
# Out:
# dtype('float64')

# %%
#drop nas in year
data.dropna(subset=["birthyear"], inplace=True)
len(data)
# Out:
# 10118

# %%
#drop where year is less than 1500 - prob won't have an accurate birthdate
data = data.drop(data[data['birthyear'] < 1500].index)
data.head(100)
# Out:
#                  name                           birthcity birthstate  \
# 0     Abraham Lincoln                         Hodgenville         KY
# 2            Ayn Rand                    Saint Petersburg        NaN
# 3        Andre Agassi                           Las Vegas         NV
# 4       Aldous Huxley                           Godalming        NaN
# 5    Andrei Tarkovsky                           Zavrazhye        NaN
# ..                ...                                 ...        ...
# 169      Ariel Sharon                          Kfar Malal        NaN
# 170  Alexey Pazhitnov                              Moscow        NaN
# 171      `Abdu'l-Bahá                              Tehran        NaN
# 172    Akira Toriyama                              Nagoya        NaN
# 173      Alec Baldwin  Long Island (ex Queens & Brooklyn)         NY
#
#         countryName countryCode3  continentName  birthyear  gender  \
# 0     UNITED STATES          USA  North America     1809.0    Male
# 2            Russia          RUS         Europe     1905.0  Female
# 3     UNITED STATES          USA  North America     1970.0    Male
# 4    UNITED KINGDOM          GBR         Europe     1894.0    Male
# 5            Russia          RUS         Europe     1932.0    Male
# ..              ...          ...            ...        ...     ...
# 169          Israel          ISR           Asia     1928.0    Male
# 170          Russia          RUS         Europe     1956.0    Male
# 171            Iran          IRN           Asia     1844.0    Male
# 172           JAPAN          JPN           Asia     1955.0    Male
# 173   UNITED STATES          USA  North America     1958.0    Male
#
#              occupation           industry                domain
# 0            POLITICIAN         GOVERNMENT          INSTITUTIONS
# 2                WRITER           LANGUAGE            HUMANITIES
# 3         TENNIS PLAYER  INDIVIDUAL SPORTS                SPORTS
# 4                WRITER           LANGUAGE            HUMANITIES
# 5         FILM DIRECTOR   FILM AND THEATRE                  ARTS
# ..                  ...                ...                   ...
# 169          POLITICIAN         GOVERNMENT          INSTITUTIONS
# 170  COMPUTER SCIENTIST   COMPUTER SCIENCE  SCIENCE & TECHNOLOGY
# 171    RELIGIOUS FIGURE           RELIGION          INSTITUTIONS
# 172        COMIC ARTIST             DESIGN                  ARTS
# 173               ACTOR   FILM AND THEATRE                  ARTS
#
# [100 rows x 11 columns]

# %%
#convert birthyear to int
data['birthyear'] = data['birthyear'].astype('int64')

# %%
#determine the number of words in each name field
data["WordsCt"] = data["name"].apply(lambda n: len(n.split()))

# %%
#find and extract instances where names don't fit normal first/middle/last naming conventions
#def naming_exceptions(row):
 #   if ',' in row['name']:
  #          name2, othername = row['name'].split(',', 1)
   #         return pd.Series({'name2': name2, 'othername': othername})
    #else:
     #   return pd.Series({'name2': None, 'othername': None})
#data = pd.concat([data, data.apply(naming_exceptions, axis=1)], axis=1)

#def royalty (row):
 #   if '' in row['name']:
  #          name2, othername = row['name'].split(',', 1)
   #         return pd.Series({'name2': name2, 'othername': othername})
    #else:
     #   return pd.Series({'name2': None, 'othername': None})
#data = pd.concat([data, data.apply(naming_exceptions, axis=1)], axis=1)

# %%
# split items without a firstname into first, middle, last 

def split_names(row):
    if row['WordsCt'] == 2:
        first, last = row['name'].split()[:2]
        return pd.Series({'firstname': first, 'lastname': last})
    elif row['WordsCt'] == 3:
        first, middle, last = row['name'].split()[:3]
        return pd.Series({'firstname': first, 'middlename': middle, 'lastname': last})
    elif row['WordsCt'] == 1:
        first = row['name'].split()[:1]
        return pd.Series({'firstname': row['name'], 'middlename': None, 'lastname': None})        
    
    else:
        return pd.Series({'firstname': None, 'middlename': None, 'lastname': None})

# Apply the split_names function and concatenate the result to the original DataFrame
data = pd.concat([data, data.apply(split_names, axis=1)], axis=1)

data.head(20)
# Out:
#                      name         birthcity birthstate     countryName  \
# 0         Abraham Lincoln       Hodgenville         KY   UNITED STATES
# 2                Ayn Rand  Saint Petersburg        NaN          Russia
# 3            Andre Agassi         Las Vegas         NV   UNITED STATES
# 4           Aldous Huxley         Godalming        NaN  UNITED KINGDOM
# 5        Andrei Tarkovsky         Zavrazhye        NaN          Russia
# 6     Arthur Schopenhauer            Gdańsk        NaN          POLAND
# 7         Albert Einstein               Ulm        NaN         Germany
# 9        Alfred Hitchcock       Leytonstone        NaN  UNITED KINGDOM
# 11           Alfred Nobel         Stockholm        NaN          SWEDEN
# 12  Alexander Graham Bell         Edinburgh        NaN  UNITED KINGDOM
# 13            Andy Warhol        Pittsburgh         PA   UNITED STATES
# 15         Akira Kurosawa             Tokyo        NaN           JAPAN
# 16        Anna Kournikova            Moscow        NaN          Russia
# 17          Andrey Markov            Ryazan        NaN          Russia
# 18            A. A. Milne         Hampstead        NaN  UNITED KINGDOM
# 19           Melvil Dewey      Adams Center         NY   United States
# 20           Albert Speer          Mannheim        NaN         GERMANY
# 21           Ada Lovelace            London        NaN  UNITED KINGDOM
# 22           Albert Camus             Dréan        NaN         ALGERIA
# 23        Agatha Christie           Torquay        NaN  UNITED KINGDOM
#
#    countryCode3  continentName  birthyear  gender     occupation  \
# 0           USA  North America       1809    Male     POLITICIAN
# 2           RUS         Europe       1905  Female         WRITER
# 3           USA  North America       1970    Male  TENNIS PLAYER
# 4           GBR         Europe       1894    Male         WRITER
# 5           RUS         Europe       1932    Male  FILM DIRECTOR
# 6           POL         Europe       1788    Male    PHILOSOPHER
# 7           DEU         Europe       1879    Male      PHYSICIST
# 9           GBR         Europe       1899    Male  FILM DIRECTOR
# 11          SWE         Europe       1833    Male        CHEMIST
# 12          GBR         Europe       1847    Male       INVENTOR
# 13          USA  North America       1928    Male         ARTIST
# 15          JPN           Asia       1910    Male  FILM DIRECTOR
# 16          RUS         Europe       1981  Female  TENNIS PLAYER
# 17          RUS         Europe       1856    Male  MATHEMATICIAN
# 18          GBR         Europe       1882    Male         WRITER
# 19          USA  North America       1851    Male       INVENTOR
# 20          DEU         Europe       1905    Male      ARCHITECT
# 21          GBR         Europe       1815  Female  MATHEMATICIAN
# 22          DZA         Africa       1913    Male         WRITER
# 23          GBR         Europe       1890  Female         WRITER
#
#              industry                domain  WordsCt  firstname      lastname  \
# 0          GOVERNMENT          INSTITUTIONS        2    Abraham       Lincoln
# 2            LANGUAGE            HUMANITIES        2        Ayn          Rand
# 3   INDIVIDUAL SPORTS                SPORTS        2      Andre        Agassi
# 4            LANGUAGE            HUMANITIES        2     Aldous        Huxley
# 5    FILM AND THEATRE                  ARTS        2     Andrei     Tarkovsky
# 6          PHILOSOPHY            HUMANITIES        2     Arthur  Schopenhauer
# 7    NATURAL SCIENCES  SCIENCE & TECHNOLOGY        2     Albert      Einstein
# 9    FILM AND THEATRE                  ARTS        2     Alfred     Hitchcock
# 11   NATURAL SCIENCES  SCIENCE & TECHNOLOGY        2     Alfred         Nobel
# 12          INVENTION  SCIENCE & TECHNOLOGY        3  Alexander          Bell
# 13          FINE ARTS                  ARTS        2       Andy        Warhol
# 15   FILM AND THEATRE                  ARTS        2      Akira      Kurosawa
# 16  INDIVIDUAL SPORTS                SPORTS        2       Anna    Kournikova
# 17               MATH  SCIENCE & TECHNOLOGY        2     Andrey        Markov
# 18           LANGUAGE            HUMANITIES        3         A.         Milne
# 19          INVENTION  SCIENCE & TECHNOLOGY        2     Melvil         Dewey
# 20             DESIGN                  ARTS        2     Albert         Speer
# 21               MATH  SCIENCE & TECHNOLOGY        2        Ada      Lovelace
# 22           LANGUAGE            HUMANITIES        2     Albert         Camus
# 23           LANGUAGE            HUMANITIES        2     Agatha      Christie
#
#    middlename
# 0         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 9         NaN
# 11        NaN
# 12     Graham
# 13        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18         A.
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN

# %%
#drop rows that could not be split out
data = data.dropna(subset=['firstname'])
len(data)
# Out:
# 8867

# %%
#create people look-up 
#get the first 3 letters of the first and last name
#cast year to a string and concatenate to create a value to join with other dataset
data['First3'] = data['firstname'].str[:3]
data['Last3'] = data['lastname'].str[:3]
data['birthyear2'] = data['birthyear'].astype(str)
data['People_Lookup'] = data['First3'] + data['Last3'] + data['birthyear2']
data = data.drop(columns=['WordsCt', 'First3', 'Last3', 'birthyear2', 'birthyear'])

data.head(10)
# Out:
#                      name         birthcity birthstate     countryName  \
# 0         Abraham Lincoln       Hodgenville         KY   UNITED STATES
# 2                Ayn Rand  Saint Petersburg        NaN          Russia
# 3            Andre Agassi         Las Vegas         NV   UNITED STATES
# 4           Aldous Huxley         Godalming        NaN  UNITED KINGDOM
# 5        Andrei Tarkovsky         Zavrazhye        NaN          Russia
# 6     Arthur Schopenhauer            Gdańsk        NaN          POLAND
# 7         Albert Einstein               Ulm        NaN         Germany
# 9        Alfred Hitchcock       Leytonstone        NaN  UNITED KINGDOM
# 11           Alfred Nobel         Stockholm        NaN          SWEDEN
# 12  Alexander Graham Bell         Edinburgh        NaN  UNITED KINGDOM
#
#    countryCode3  continentName  gender     occupation           industry  \
# 0           USA  North America    Male     POLITICIAN         GOVERNMENT
# 2           RUS         Europe  Female         WRITER           LANGUAGE
# 3           USA  North America    Male  TENNIS PLAYER  INDIVIDUAL SPORTS
# 4           GBR         Europe    Male         WRITER           LANGUAGE
# 5           RUS         Europe    Male  FILM DIRECTOR   FILM AND THEATRE
# 6           POL         Europe    Male    PHILOSOPHER         PHILOSOPHY
# 7           DEU         Europe    Male      PHYSICIST   NATURAL SCIENCES
# 9           GBR         Europe    Male  FILM DIRECTOR   FILM AND THEATRE
# 11          SWE         Europe    Male        CHEMIST   NATURAL SCIENCES
# 12          GBR         Europe    Male       INVENTOR          INVENTION
#
#                   domain  firstname      lastname middlename People_Lookup
# 0           INSTITUTIONS    Abraham       Lincoln        NaN    AbrLin1809
# 2             HUMANITIES        Ayn          Rand        NaN    AynRan1905
# 3                 SPORTS      Andre        Agassi        NaN    AndAga1970
# 4             HUMANITIES     Aldous        Huxley        NaN    AldHux1894
# 5                   ARTS     Andrei     Tarkovsky        NaN    AndTar1932
# 6             HUMANITIES     Arthur  Schopenhauer        NaN    ArtSch1788
# 7   SCIENCE & TECHNOLOGY     Albert      Einstein        NaN    AlbEin1879
# 9                   ARTS     Alfred     Hitchcock        NaN    AlfHit1899
# 11  SCIENCE & TECHNOLOGY     Alfred         Nobel        NaN    AlfNob1833
# 12  SCIENCE & TECHNOLOGY  Alexander          Bell     Graham    AleBel1847

# %%
#write to table in SQLlite db

import sqlite3
connection = sqlite3.connect('Zodiac_Analysis.db')
data.to_sql('Pantheon_People_Import', connection, if_exists='replace')
# Out:
# 8867
